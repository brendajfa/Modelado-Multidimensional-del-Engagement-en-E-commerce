# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install "drive/MyDrive/Master Data Science/TFM/GITHUB/modelado_multidimensional_engagement-0.1.0-py3-none-any.whl"
# Out:
# Mounted at /content/drive
# Processing ./drive/MyDrive/Master Data Science/TFM/GITHUB/modelado_multidimensional_engagement-0.1.0-py3-none-any.whl
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from modelado-multidimensional-engagement==0.1.0) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from modelado-multidimensional-engagement==0.1.0) (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from modelado-multidimensional-engagement==0.1.0) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from modelado-multidimensional-engagement==0.1.0) (1.16.3)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from modelado-multidimensional-engagement==0.1.0) (18.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->modelado-multidimensional-engagement==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->modelado-multidimensional-engagement==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->modelado-multidimensional-engagement==0.1.0) (2026.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->modelado-multidimensional-engagement==0.1.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->modelado-multidimensional-engagement==0.1.0) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->modelado-multidimensional-engagement==0.1.0) (1.17.0)
# Installing collected packages: modelado-multidimensional-engagement
# Successfully installed modelado-multidimensional-engagement-0.1.0

# %%
import pandas as pd
import os

from src.preprocessing.general import GeneralPreprocessor
from src.preprocessing.user_based import UserBasedPreprocessor
from src.preprocessing.time_based import TimeBasedPreprocessor
from src import config

# %%
config.CATEGORY_CODES
# Out:
# ['electronics.video.tv',
#  'computers.components.memory',
#  'computers.components.motherboard',
#  'appliances.kitchen.juicer']

# %%
config.WORKPATH
# Out:
# 'drive/MyDrive/Master Data Science/TFM/GITHUB'

# %%
general_preprocessor = GeneralPreprocessor()
user_based_preprocessor = UserBasedPreprocessor()
time_based_preprocessor = TimeBasedPreprocessor()

# %%
general_metrics = general_preprocessor.process(train_eval="training_201911")
user_based_metrics = user_based_preprocessor.process(train_eval="training_201911")
time_based_metrics = time_based_preprocessor.process(train_eval="training_201911")
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Procesando: electronics.video.tv
#  25%|██▌       | 1/4 [02:07<06:22, 127.55s/it]
# Procesando: computers.components.memory
#  50%|█████     | 2/4 [02:16<01:55, 57.56s/it]
# Procesando: computers.components.motherboard
#  75%|███████▌  | 3/4 [02:23<00:34, 34.87s/it]
# Procesando: appliances.kitchen.juicer
# 100%|██████████| 4/4 [02:30<00:00, 37.61s/it]
# Resultados guardados en: drive/MyDrive/Master Data Science/TFM/GITHUB/processed/training_201911/aggregated_generic.parquet
#   0%|          | 0/4 [00:00<?, ?it/s]
# Procesando: electronics.video.tv
#  25%|██▌       | 1/4 [02:03<06:10, 123.59s/it]
# Procesando: computers.components.memory
#  50%|█████     | 2/4 [02:09<01:49, 54.52s/it]
# Procesando: computers.components.motherboard
#  75%|███████▌  | 3/4 [02:15<00:32, 32.35s/it]
# Procesando: appliances.kitchen.juicer
# 100%|██████████| 4/4 [02:20<00:00, 35.06s/it]
# Resultados guardados en: drive/MyDrive/Master Data Science/TFM/GITHUB/processed/training_201911/user_based_metrics.parquet
#   0%|          | 0/4 [00:00<?, ?it/s]
# Procesando: electronics.video.tv
#  25%|██▌       | 1/4 [02:03<06:09, 123.28s/it]
# Procesando: computers.components.memory
#  50%|█████     | 2/4 [02:09<01:48, 54.35s/it]
# Procesando: computers.components.motherboard
#  75%|███████▌  | 3/4 [02:15<00:32, 32.27s/it]
# Procesando: appliances.kitchen.juicer
# 100%|██████████| 4/4 [02:19<00:00, 34.95s/it]
# Resultados guardados en: drive/MyDrive/Master Data Science/TFM/GITHUB/processed/training_201911/time_based_metrics.parquet

# %%
general_metrics
# Out:
#                       category_code  visits   users   clicks  click_depth  \
# 0              electronics.video.tv  508941  260719  1190621     2.341212
# 1       computers.components.memory   25687   12212    50017     1.948309
# 2  computers.components.motherboard   24796   10435    48204     1.944651
# 3         appliances.kitchen.juicer   18493   12939    41810     2.261834
#
#    dwell_time_avg  active_days  return_rate  dwelltime_l
# 0      334.690761     1.496381     1.952071   653.339261
# 1      134.618795     1.510481     2.103423   283.160252
# 2      331.083037     1.578438     2.376234   786.730713
# 3      184.385983     1.216477     1.429245   263.532730

# %%
user_based_metrics
# Out:
#                       category_code  Tourist_users  Tourist_visits  \
# 0              electronics.video.tv         193113          223650
# 1       computers.components.memory           9163           11703
# 2  computers.components.motherboard           7737           10095
# 3         appliances.kitchen.juicer          11127           12321
#
#    Interested_users  Interested_visits  Average_users  Average_visits  \
# 0             60013             198515           6484           61277
# 1              2634               9478            345            3180
# 2              2247               9008            350            3631
# 3              1721               5283             83             729
#
#    Active_users  Active_visits  VIP_users  ...  Tourist_return_rate  \
# 0          1009          20882        100  ...             1.158135
# 1            66           1202          4  ...             1.277202
# 2            99           1982          2  ...             1.304769
# 3             7            117          1  ...             1.107307
#
#    Interested_return_rate  Average_return_rate  Active_return_rate  \
# 0                3.307867             9.450494           20.695738
# 1                3.598330             9.217391           18.212121
# 2                4.008901            10.374286           20.020202
# 3                3.069727             8.783133           16.714286
#
#    VIP_return_rate  Tourist_dwelltime_l  Interested_dwelltime_l  \
# 0            46.17           177.246436             1484.064419
# 1            31.00            99.818509              527.283979
# 2            40.00           116.282538             2201.036493
# 3            43.00           157.038914              842.167345
#
#    Average_dwelltime_l  Active_dwelltime_l  VIP_dwelltime_l
# 0          4174.165793         8561.593657        113422.71
# 1          2762.672464         2952.742424          1611.75
# 2          5463.734286         4413.797980          7427.50
# 3          2232.493976         2166.571429         12645.00
#
# [4 rows x 41 columns]

# %%
time_based_metrics
# Out:
#                       category_code     users    visits    clicks  \
# 0              electronics.video.tv  0.609968  0.635513  0.621812
# 1       computers.components.memory  0.647557  0.694784  0.682868
# 2  computers.components.motherboard  0.643746  0.691734  0.679466
# 3         appliances.kitchen.juicer  0.605822  0.618978  0.594451
#
#    click_depth  dwell_time_avg  return_rate  dwelltime_l
# 0     0.478314        0.525364     0.527163     0.552385
# 1     0.482831        0.441739     0.553362     0.495039
# 2     0.482706        0.565750     0.553933     0.618009
# 3     0.467457        0.440700     0.513854     0.454404

# %%
general_metrics_dic = general_preprocessor.process(train_eval="evaluation_201912")
user_based_metrics_dic = user_based_preprocessor.process(train_eval="evaluation_201912")
time_based_metrics_dic = time_based_preprocessor.process(train_eval="evaluation_201912")
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Procesando: electronics.video.tv
#  25%|██▌       | 1/4 [00:44<02:13, 44.37s/it]
# Procesando: computers.components.memory
#  50%|█████     | 2/4 [00:48<00:41, 20.64s/it]
# Procesando: computers.components.motherboard
#  75%|███████▌  | 3/4 [00:53<00:13, 13.67s/it]
# Procesando: appliances.kitchen.juicer
# 100%|██████████| 4/4 [01:10<00:00, 17.68s/it]
# Resultados guardados en: drive/MyDrive/Master Data Science/TFM/GITHUB/processed/evaluation_201912/aggregated_generic.parquet
#   0%|          | 0/4 [00:00<?, ?it/s]
# Procesando: electronics.video.tv
#  25%|██▌       | 1/4 [00:40<02:01, 40.65s/it]
# Procesando: computers.components.memory
#  50%|█████     | 2/4 [00:42<00:36, 18.00s/it]
# Procesando: computers.components.motherboard
#  75%|███████▌  | 3/4 [00:46<00:11, 11.31s/it]
# Procesando: appliances.kitchen.juicer
# 100%|██████████| 4/4 [01:00<00:00, 15.10s/it]
# Resultados guardados en: drive/MyDrive/Master Data Science/TFM/GITHUB/processed/evaluation_201912/user_based_metrics.parquet
#   0%|          | 0/4 [00:00<?, ?it/s]
# Procesando: electronics.video.tv
#  25%|██▌       | 1/4 [00:39<01:59, 39.97s/it]
# Procesando: computers.components.memory
#  50%|█████     | 2/4 [00:42<00:35, 17.75s/it]
# Procesando: computers.components.motherboard
#  75%|███████▌  | 3/4 [00:45<00:11, 11.16s/it]
# Procesando: appliances.kitchen.juicer
# 100%|██████████| 4/4 [00:59<00:00, 14.89s/it]
# Resultados guardados en: drive/MyDrive/Master Data Science/TFM/GITHUB/processed/evaluation_201912/time_based_metrics.parquet

# %%
general_metrics_dic
# Out:
#                       category_code  visits   users  clicks  click_depth  \
# 0              electronics.video.tv  168605  104858  325528     1.930828
# 1       computers.components.memory    9062    5290   11454     1.263959
# 2  computers.components.motherboard   14294   11378   20132     1.408522
# 3         appliances.kitchen.juicer   59727   36292   92480     1.548586
#
#    dwell_time_avg  active_days  return_rate  dwelltime_l
# 0      242.928133     1.317305     1.607936   390.613000
# 1       89.352350     1.345369     1.713043   153.064461
# 2       47.119070     1.146247     1.256284    59.194937
# 3      213.331575     1.290339     1.645735   351.087154

# %%
user_based_metrics_dic
# Out:
#                       category_code  Tourist_users  Tourist_visits  \
# 0              electronics.video.tv        85354.0         93474.0
# 1       computers.components.memory         4263.0          4996.0
# 2  computers.components.motherboard        10394.0         10895.0
# 3         appliances.kitchen.juicer        30369.0         35656.0
#
#    Interested_users  Interested_visits  Average_users  Average_visits  \
# 0           17949.0            53190.0         1341.0         12080.0
# 1             933.0             3021.0           81.0           773.0
# 2             899.0             2565.0           77.0           685.0
# 3            5392.0            17799.0          423.0          3920.0
#
#    Active_users  Active_visits  VIP_users  ...  Tourist_return_rate  \
# 0         192.0         4481.0       22.0  ...             1.095133
# 1          13.0          272.0        0.0  ...             1.171945
# 2           8.0          149.0        0.0  ...             1.048201
# 3          96.0         1894.0       12.0  ...             1.174092
#
#    Interested_return_rate  Average_return_rate  Active_return_rate  \
# 0                2.963396             9.008203           23.338542
# 1                3.237942             9.543210           20.923077
# 2                2.853170             8.896104           18.625000
# 3                3.301001             9.267139           19.729167
#
#    VIP_return_rate  Tourist_dwelltime_l  Interested_dwelltime_l  \
# 0       244.545455           107.061403             1262.212658
# 1         0.000000            49.865353              470.988210
# 2         0.000000            32.978160              287.001112
# 3        38.166667            75.871481             1352.361647
#
#    Average_dwelltime_l  Active_dwelltime_l  VIP_dwelltime_l
# 0          6160.544370         4015.807292      6045.409091
# 1          1263.518519         4258.307692         0.000000
# 2           801.441558         1377.500000         0.000000
# 3          6663.257683         2529.843750      7013.083333
#
# [4 rows x 41 columns]

# %%
time_based_metrics_dic
# Out:
#                       category_code     users    visits    clicks  \
# 0              electronics.video.tv  0.685747  0.715474  0.713383
# 1       computers.components.memory  0.684444  0.702085  0.698708
# 2  computers.components.motherboard  0.713803  0.729817  0.725015
# 3         appliances.kitchen.juicer  0.689187  0.712117  0.708348
#
#    click_depth  dwell_time_avg  return_rate  dwelltime_l
# 0     0.497675        0.525561     0.535393     0.560735
# 1     0.496466        0.549277     0.520732     0.569724
# 2     0.494701        0.538267     0.519931     0.558021
# 3     0.494386        0.501258     0.527314     0.528568
